# %% [markdown]
# ## Let's understand the intuition behind CNN

# %% [markdown]
# * A convolutional neural network (CNN), is a network architecture for deep learning which learns directly from data. CNNs are particularly useful for finding patterns in images to recognize objects

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Convolution Neural Networks have 3 main layers :
#     * **Convolutional layer**
#     * **Pooling layer**
#     * **Fully-connected (FC) layer**

# %% [markdown]
# ### Convolutional layer
#
# * The convolutional layer is the core building block of a CNN, and it is where the majority of computation occurs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import Image
Image(filename='giphy.gif')

# %% [markdown]
# * if you have a **n*n** image and you convolve it by **f * f** filter (or kernel) you end up by a **(n-f+1) * (n-f+1)** image matrix

# %% [markdown]
# * **Stide**:
#    *  the stride is the number of pixels by which the convolution kernel is moved when convolving the input image
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * **Padding** :
#     * padding is the number of pixels added to the edges of the input image to preserve the spatial dimensions of the output feature maps during the convolution operation.
#     * There are two types of padding: "same" and "valid":
#
#          * **same padding** preserves the spatial dimensions of the input image by adding an appropriate number of pixels to the edges of the input image so that the output feature maps have the same spatial dimensions as the input image. :  p = (f-1)/2
#          * **valid padding** means that no padding is added to the edges of the input image. The output feature maps will have smaller spatial dimensions than the input image. : p=0

# %% [markdown]
# * ==> if you have **n*n** image , **f*f** filter , amount of padding **p** , strided with **s** then the output size will be **[(n+2p-f)/s] +1 * [(n+2p-f)/s] +1**

# %% [markdown]
# ### Pooling Layer

# %% [markdown]
# * also known as downsampling, conducts dimensionality reduction
# * two main types of pooling:
#     * **Max pooling**
#     * **Average pooling**
#     ==> Max pooling is used more often compared to average pooling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TODO :
# test the operations and formulas manually
# Upload the code to google colab

# %% [markdown]
# ## Additional links
# * https://medium.com/@draj0718/convolutional-neural-networks-cnn-architectures-explained-716fb197b243
#
# * https://www.ibm.com/topics/convolutional-neural-networks

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt # for images and metrics visualization
import numpy as np # to manipulation nd arrays 
import tensorflow as tf # for tensors manipulation and deep learning models developing
import pathlib # for paths manipulation

from tensorflow import keras # keras is a high level api to develop DL architectures
from tensorflow.keras import layers # the modules to create different model layers
from tensorflow.keras.models import Sequential # to instansiate the model architecture

# %%
# store directories paths 
train_dir = pathlib.Path("train")  
test_dir = pathlib.Path("test") 

# count the number of images in each folder (train / test)
train_image_count = len(list(train_dir.glob('*/*.png')))  
test_image_count = len(list(test_dir.glob('*/*.png')))
print(train_image_count)
print(test_image_count)
# Out:
# 28709
# 7178

# %% [markdown]
# ## Load and split data into train , validation , test set

# %%
# initiate our hyperparameters
batch_size = 32
img_height = 48
img_width = 48

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(train_dir,validation_split=0.2,subset="training",seed=123,
                                                       image_size=(img_height, img_width),batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(train_dir,validation_split=0.2,subset="validation",seed=123,image_size=(img_height, img_width),batch_size=batch_size)
test_ds = tf.keras.utils.image_dataset_from_directory(test_dir, seed=123,image_size=(img_height, img_width),batch_size=batch_size)
# Out:
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.
# Found 7178 files belonging to 7 classes.

# %%
# Extract classes 
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %% [markdown]
# ## Visualize Images

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
#  * cache() is used to cache the dataset in memory, which can improve the performance of the training process by avoiding the need to re-read the data from the source each time it is used.
#
# * shuffle(1000) shuffles the dataset, so that the examples are presented in a random order. This can be important for ensuring that the model is not over-fitting to any particular sequence of examples. The number 1000 in this case specifies the size of the buffer to use when shuffling the data.
#
# * prefetch(buffer_size=AUTOTUNE) is used to improve the performance of the training process by prefetching examples for the next step in the training loop. This can help to hide the latency of reading data from the source and can improve the overall throughput of the training process. The buffer_size parameter specifies the number of examples to prefetch. The value AUTOTUNE indicates that the prefetch buffer size should be automatically tuned for the best performance.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Build CNN model

# %% [markdown]
# **To Understand CNN architecture check https://poloclub.github.io/cnn-explainer/**

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 48, 48, 3)         0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 16)        448
#
#  max_pooling2d_3 (MaxPooling  (None, 24, 24, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 128)               295040
#
#  dense_3 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 319,527
# Trainable params: 319,527
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 718/718 [==============================] - 21s 29ms/step - loss: 1.6397 - accuracy: 0.3523 - val_loss: 1.5074 - val_accuracy: 0.4184
# Epoch 2/10
# 718/718 [==============================] - 23s 32ms/step - loss: 1.3952 - accuracy: 0.4669 - val_loss: 1.3570 - val_accuracy: 0.4740
# Epoch 3/10
# 718/718 [==============================] - 22s 31ms/step - loss: 1.2679 - accuracy: 0.5202 - val_loss: 1.3109 - val_accuracy: 0.4931
# Epoch 4/10
# 718/718 [==============================] - 21s 30ms/step - loss: 1.1770 - accuracy: 0.5544 - val_loss: 1.2798 - val_accuracy: 0.5172
# Epoch 5/10
# 718/718 [==============================] - 24s 34ms/step - loss: 1.0894 - accuracy: 0.5874 - val_loss: 1.2775 - val_accuracy: 0.5210
# Epoch 6/10
# 718/718 [==============================] - 25s 34ms/step - loss: 1.0042 - accuracy: 0.6223 - val_loss: 1.2664 - val_accuracy: 0.5335
# Epoch 7/10
# 718/718 [==============================] - 24s 34ms/step - loss: 0.9239 - accuracy: 0.6599 - val_loss: 1.3352 - val_accuracy: 0.5314
# Epoch 8/10
# 718/718 [==============================] - 23s 32ms/step - loss: 0.8263 - accuracy: 0.6953 - val_loss: 1.3473 - val_accuracy: 0.5217
# Epoch 9/10
# 718/718 [==============================] - 24s 34ms/step - loss: 0.7278 - accuracy: 0.7355 - val_loss: 1.4469 - val_accuracy: 0.5300
# Epoch 10/10
# 718/718 [==============================] - 22s 31ms/step - loss: 0.6401 - accuracy: 0.7652 - val_loss: 1.5646 - val_accuracy: 0.5248

# %% [markdown]
# ## Evaluate the model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# * The plots show that training accuracy and validation accuracy are off by large margins.
# * ==> This is a sign of overfitting

# %% [markdown]
# ### Data augmentation
#
# Overfitting generally occurs when there are a small number of training examples. Data augmentation takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Rebuild the model with data augmentation layer

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 48, 48, 3)         0
#
#  rescaling_2 (Rescaling)     (None, 48, 48, 3)         0
#
#  conv2d_6 (Conv2D)           (None, 48, 48, 16)        448
#
#  max_pooling2d_6 (MaxPooling  (None, 24, 24, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 6, 6, 64)          0
#
#  flatten_2 (Flatten)         (None, 2304)              0
#
#  dense_4 (Dense)             (None, 128)               295040
#
#  outputs (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 319,527
# Trainable params: 319,527
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlyStoppingCallback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                                         patience=5,
                                                         verbose= 1 ,
                                                         restore_best_weights=True
                                                        )

epochs = 100
history = model.fit(train_ds,validation_data=val_ds,epochs=epochs, callbacks= [earlyStoppingCallback])
# Out:
# Epoch 1/100
# 718/718 [==============================] - 25s 32ms/step - loss: 1.7569 - accuracy: 0.2786 - val_loss: 1.6949 - val_accuracy: 0.3167
# Epoch 2/100
# 718/718 [==============================] - 25s 34ms/step - loss: 1.6481 - accuracy: 0.3460 - val_loss: 1.5549 - val_accuracy: 0.4020
# Epoch 3/100
# 718/718 [==============================] - 25s 35ms/step - loss: 1.5599 - accuracy: 0.3965 - val_loss: 1.4858 - val_accuracy: 0.4329
# Epoch 4/100
# 718/718 [==============================] - 27s 38ms/step - loss: 1.4958 - accuracy: 0.4209 - val_loss: 1.4217 - val_accuracy: 0.4581
# Epoch 5/100
# 718/718 [==============================] - 27s 38ms/step - loss: 1.4404 - accuracy: 0.4412 - val_loss: 1.4117 - val_accuracy: 0.4656
# Epoch 6/100
# 718/718 [==============================] - 26s 37ms/step - loss: 1.4040 - accuracy: 0.4605 - val_loss: 1.3703 - val_accuracy: 0.4792
# Epoch 7/100
# 718/718 [==============================] - 26s 36ms/step - loss: 1.3738 - accuracy: 0.4704 - val_loss: 1.3179 - val_accuracy: 0.5017
# Epoch 8/100
# 718/718 [==============================] - 27s 37ms/step - loss: 1.3423 - accuracy: 0.4879 - val_loss: 1.2927 - val_accuracy: 0.5051
# Epoch 9/100
# 718/718 [==============================] - 27s 38ms/step - loss: 1.3228 - accuracy: 0.4916 - val_loss: 1.2944 - val_accuracy: 0.5118
# Epoch 10/100
# 718/718 [==============================] - 26s 37ms/step - loss: 1.3038 - accuracy: 0.5013 - val_loss: 1.2859 - val_accuracy: 0.5078
# Epoch 11/100
# 718/718 [==============================] - 27s 38ms/step - loss: 1.2814 - accuracy: 0.5081 - val_loss: 1.2604 - val_accuracy: 0.5208
# Epoch 12/100
# 718/718 [==============================] - 27s 38ms/step - loss: 1.2650 - accuracy: 0.5149 - val_loss: 1.2583 - val_accuracy: 0.5238
# Epoch 13/100
# 718/718 [==============================] - 26s 37ms/step - loss: 1.2542 - accuracy: 0.5207 - val_loss: 1.2712 - val_accuracy: 0.5278
# Epoch 14/100
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2475 - accuracy: 0.5274 - val_loss: 1.2271 - val_accuracy: 0.5321
# Epoch 15/100
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2375 - accuracy: 0.5245 - val_loss: 1.2331 - val_accuracy: 0.5365
# Epoch 16/100
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2275 - accuracy: 0.5350 - val_loss: 1.2416 - val_accuracy: 0.5313
# Epoch 17/100
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2164 - accuracy: 0.5390 - val_loss: 1.2193 - val_accuracy: 0.5424
# Epoch 18/100
# 718/718 [==============================] - 25s 35ms/step - loss: 1.2124 - accuracy: 0.5383 - val_loss: 1.2083 - val_accuracy: 0.5412
# Epoch 19/100
# 718/718 [==============================] - 25s 35ms/step - loss: 1.1999 - accuracy: 0.5428 - val_loss: 1.2340 - val_accuracy: 0.5360
# Epoch 20/100
# 718/718 [==============================] - 25s 35ms/step - loss: 1.1980 - accuracy: 0.5415 - val_loss: 1.2031 - val_accuracy: 0.5482
# Epoch 21/100
# 718/718 [==============================] - 25s 35ms/step - loss: 1.1897 - accuracy: 0.5505 - val_loss: 1.2224 - val_accuracy: 0.5386
# Epoch 22/100
# 718/718 [==============================] - 25s 35ms/step - loss: 1.1868 - accuracy: 0.5482 - val_loss: 1.2365 - val_accuracy: 0.5372
# Epoch 23/100
# 718/718 [==============================] - 26s 36ms/step - loss: 1.1842 - accuracy: 0.5465 - val_loss: 1.2072 - val_accuracy: 0.5440
# Epoch 24/100
# 718/718 [==============================] - 26s 36ms/step - loss: 1.1707 - accuracy: 0.5559 - val_loss: 1.2098 - val_accuracy: 0.5497
# Epoch 25/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.1677 - accuracy: 0.5523Restoring model weights from the end of the best epoch: 20.
# 718/718 [==============================] - 26s 36ms/step - loss: 1.1679 - accuracy: 0.5525 - val_loss: 1.2037 - val_accuracy: 0.5466
# Epoch 25: early stopping

# %% [markdown]
# ## Evaluate the final model on the test set

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(test_ds)

# Print the loss and accuracy
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 225/225 [==============================] - 7s 17ms/step - loss: 1.1957 - accuracy: 0.5467
# Loss:  1.1957041025161743
# Accuracy:  0.5466703772544861

# %%
im_path = "test/happy/im5.png"
img = tf.keras.utils.load_img(
    im_path, target_size=(img_height, img_width)
)
print(img.size)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
print(img_array.shape)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# (48, 48)
# (1, 48, 48, 3)
# 1/1 [==============================] - 0s 18ms/step
# This image most likely belongs to happy with a 98.46 percent confidence.

# %%
model.save("EmotionDetecttor_2")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: EmotionDetecttor_2/assets
# INFO:tensorflow:Assets written to: EmotionDetecttor_2/assets

# %%
recons_model = tf.keras.models.load_model("EmotionDetecttor_2")

# %%
pr = recons_model.predict(img_array)
sc=tf.nn.softmax(pr[0])
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(sc)], 100 * np.max(sc))
)
# Out:
# 1/1 [==============================] - 0s 79ms/step
# This image most likely belongs to happy with a 98.46 percent confidence.
